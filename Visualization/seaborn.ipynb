# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(df, x='survived', hue='sex')
plt.title('Survived vs Not Survived by gender')
plt.show()

# %%
sns.countplot(df, x='class', palette= 'viridis')
plt.title('Number of Passengers by Class')
plt.show
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_11612\3387020188.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='class', palette= 'viridis')
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(df, x='class', y='survived', palette='coolwarm')
plt.title('Survived Rate by Class')
plt.show()
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_11612\825112303.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(df, x='class', y='survived', palette='coolwarm')

# %%
sns.histplot(df, x= 'age',bins=30, kde=True, color='red')
plt.title('Survival Rate By Age')
plt.show()

# %%
sns.violinplot(df, x='class', y='age', hue='sex',split=True, palette='Set2')
plt.title('Age Distribution by Class')
plt.show()

# %%
sns.scatterplot(df,x='age',y='fare',hue='survived',palette='viridis')
plt.title('fare vs Age by Survival' )
plt.show()

# %%
sns.pairplot(df[['age', 'fare','survived','pclass']],hue='survived', palette='terrain')
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(df, x='species',palette='spring',alpha=0.5)
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_11612\1587155951.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(df, x='species',palette='spring',alpha=0.5)
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.violinplot(df, x="petal_length",y='species')
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.boxplot(df,x='sepal_width',y='species',palette='CMRmap')
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_11612\2338428381.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df,x='sepal_width',y='species',palette='CMRmap')
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.histplot(df, x='sepal_length',kde=True,palette='Accent')
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_11612\1689740984.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df, x='sepal_length',kde=True,palette='Accent')
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.scatterplot(df, x="sepal_length",y="petal_length", hue='species', palette="spring")
plt.title('Comperesion between sepal.length')
plt.show()
